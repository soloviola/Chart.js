# %% [markdown]
# <a href="https://colab.research.google.com/github/soloviola/Chart.js/blob/master/notebooks/self_contained.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# run a shell command to install modal
# !pip install -qqq modal
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.7/558.7 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.5 MB/s eta 0:00:00

# %%
# clean up Jupyter cell outputs for shell commands a bit
# %env TERM=dumb
# Out:
# env: TERM=dumb

# %%
# setup modal, including creating an account
# !modal setup
# Out:
# Was not able to launch web browser
# Please go to this URL manually and complete the flow:
#
# https://modal.com/token-flow/tf-6w0WRByaxLjU8x7ipigZ8P
#
#
#
# Web authentication finished successfully!
# Token is connected to the suno-ai workspace.
# Verifying token against https://api.modal.com
# Token verified successfully!
#
# Token written to /root/.modal.toml in profile suno-ai.

# %%
# !git clone https://github.com/modal-labs/music-video-gen
# Out:
# Cloning into 'music-video-gen'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 108 (delta 39), reused 84 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (108/108), 6.31 MiB | 31.97 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# %cd /content/music-video-gen
# Out:
# /content/music-video-gen

# %%
# see the README for detailed instructions

# !cat README.md
# Out:
# # Deploy a personalized music video generation service on Modal
#
# Music videos are [cool](https://youtu.be/Cye-1RP5jso),
# but unless you are famous or
# [pay a lot of money](https://youtu.be/kfVsfOSbJY0),
# you don't get to star in them.
#
# Until now!
#
# [The repo](https://github.com/modal-labs/music-video-gen)
# includes all the code you need to deploy a custom
# music video generator on [Modal](https://modal.com),
# a serverless infrastructure platform for data, ML, and AI applications.
#
# Below is a sample video, generated by Modal Developer Advocate
# [`@charles_irl`](https://twitter.com/charles_irl).
#
# <center>
# <video src="https://github.com/user-attachments/assets/5bd90898-7251-4298-808f-6d58ed4c6b6f" controls>
# <track label="English" kind="captions" srclang="en" src="...">
# </video>
# </center>
#
# And because Modal is
# [generic serverless infrastructure](https://twitter.com/charles_irl/status/1819438860771663923),
# ...

# %%
# this cell launches another notebook, on Modal,
# where you can upload data and run training

# click the stop button next to this cell or select "Runtime > Interrupt execution"
# when you are done using the notebook

# !modal run train_from_notebook.py
# Out:
# ✓ Initialized. View run at
# https://modal.com/apps/suno-ai/main/ap-vwnilA82YQg48Oz97dJZII
#
# Building image im-5snXCVG6muuQN9gH9RYHBP
#
# => Step 0: FROM base
#
# => Step 1: RUN git clone https://github.com/ostris/ai-toolkit.git /root/ai-toolkit
# Cloning into '/root/ai-toolkit'...
#
# => Step 2: RUN cd /root/ai-toolkit && git submodule update --init --recursive
# Submodule 'repositories/batch_annotator' (https://github.com/ostris/batch-annotator) registered for path 'repositories/batch_annotator'
# Submodule 'repositories/ipadapter' (https://github.com/tencent-ailab/IP-Adapter.git) registered for path 'repositories/ipadapter'
# Submodule 'repositories/leco' (https://github.com/p1atdev/LECO) registered for path 'repositories/leco'
# Submodule 'repositories/sd-scripts' (https://github.com/kohya-ss/sd-scripts.git) registered for path 'repositories/sd-scripts'
# Cloning into '/root/ai-toolkit/repositories/batch_annotator'...
# Cloning into '/root/ai-toolkit/repositories/ipadapter'...
# ...

# %%
# if you didn't note the ID of your finetuned model, find it here

# !modal volume ls finetune-video-models
# Out:
#          Directory listing of '/' in
#            'finetune-video-models'
# ┏━━━━━━━━━━┳━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━┓
# ┃ Filename ┃ Type ┃ Created/Modified ┃ Size ┃
# ┡━━━━━━━━━━╇━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━┩
# └──────────┴──────┴──────────────────┴──────┘

# %%
finetune_id = None  # set it here

assert finetune_id is not None

# %%
# !modal run inference.py --finetune-id {finetune_id} --num-frames 15

# %%
# find video files

files = !find /tmp -name *.mp4
files

# %%
# display video files in notebook
import moviepy.editor

# you can also find the /tmp folder in the file browser
# to download them locally

video = files[0]
print(video)

moviepy.editor.ipython_display(video)

# %%
# deploy inference when you're ready
# !modal deploy inference.py

# %%
# once inference is deployed, you can run the music video generator
# !modal run music_video_generator.py --help

# %%
# this takes a few minutes and will consume a dollar or two of Modal resources!
# note that Modal includes $30/month of free credits
assert finetune_id is not None

# !modal run music_video_generator.py --finetune-id {finetune_id}

# %%
# find video files

files = !find /tmp -name *.mp4
files

# %%
# display video files in notebook
import moviepy.editor

# you can also find the /tmp folder in the file browser
# to download them locally

moviepy.editor.ipython_display(files[-1])
